# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import libem
import numpy as np
from libvis import Visualizations
from components import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=20)
    
sim.compute(make_enforcer(
    enf(EMObjects.rectangular_prism_solid, (0, 0, 0), (0.5, 0.5, 0.5), 1)
))
print("Done.")
# Out:
# Computed in 100 iterations.
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
Visualizations.color_xsections_3d(sim, 
                                  [(0, -0.2 + (0.1 * i)) for i in range(6)],
                                  size=(8, 8), resolution=1, color_norm=1)

# %%
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=0, location=0)
Visualizations.colormesh_2d(sim2d, color_norm=1)

# %%
Visualizations.contour_2d(sim2d)
