# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import libem
import numpy as np
from libvis import Visualizations
import matplotlib.pyplot as plt

from components import *

# %% [markdown]
# ### Point Charge

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=30)   
sim.compute(make_enforcer(
    enf(EMObjects.point_charge, (0, 0, 0), 1)
))
print("Done.")
# Out:
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=0, location=0.5)
Visualizations.colormesh_2d(sim2d, graph_ax=ax)
Visualizations.efield_2d(sim2d, graph_ax=ax)
Visualizations.contour_2d(sim2d, graph_ax=ax)
plt.show()

# %% [markdown]
# ### Rectangular Prism (Solid)

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=25)   
sim.compute(make_enforcer(
    enf(EMObjects.rectangular_prism_solid, (-0.25, -0.5, -0.1), (0.5, 1, 0.2), 1)
))
print("Done.")
# Out:
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
Visualizations.color_xsections_3d(sim, 
                                  [(0, -0.5 + (0.25 * i)) for i in range(5)],
                                  size=(8, 8), resolution=1, color_norm=1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=0, location=0)
Visualizations.colormesh_2d(sim2d, graph_ax=ax)
Visualizations.efield_2d(sim2d, graph_ax=ax)
Visualizations.contour_2d(sim2d, graph_ax=ax)
plt.show()

# %% [markdown]
# ### Rectangular Prism (Hollow)

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=25)   
sim.compute(make_enforcer(
    enf(EMObjects.rectangular_prism_hollow, (-0.4, -0.5, -0.3), (0.8, 1, 0.6), 0.05, 1)
))
print("Done.")
# Out:
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=0, location=0)
Visualizations.colormesh_2d(sim2d, graph_ax=ax)
Visualizations.efield_2d(sim2d, graph_ax=ax)
Visualizations.contour_2d(sim2d, graph_ax=ax)
plt.show()

# %% [markdown]
# ### Rectangular Prism (Hollow, No Cap)

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=25)   
sim.compute(make_enforcer(
    enf(EMObjects.rectangular_prism_hollow_nocap, (-0.4, -0.5, -0.3), (0.8, 1, 0.6), 0.05, 0, 1)
))
print("Done.")
# Out:
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=1, location=0)
Visualizations.colormesh_2d(sim2d, graph_ax=ax)
Visualizations.efield_2d(sim2d, graph_ax=ax)
Visualizations.contour_2d(sim2d, graph_ax=ax)
plt.show()

# %% [markdown]
# ### Planar Mesh

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=25)   
sim.compute(make_enforcer(
    enf(EMObjects.planar_mesh_3d, (0, -0.8, -0.8), 0, (0.1, 1.6, 1.6), (0.2, 0.2), 0.05, 1)
))
print("Done.")
# Out:
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=0, location=0)
Visualizations.colormesh_2d(sim2d, graph_ax=ax)
Visualizations.efield_2d(sim2d, graph_ax=ax)
Visualizations.contour_2d(sim2d, graph_ax=ax)
plt.show()

# %% [markdown]
# ### Ring

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=25)   
ring1_mask = EMObjectMasks.ring_in_plane(sim, (0, 0, 0), 0.5, 0.05, 0)
sim.compute(make_enforcer(
    enf(EMObjects.arbitrary_mask, ring1_mask, 1)
))
print("Done.")
# Out:
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=0, location=0)
Visualizations.colormesh_2d(sim2d, graph_ax=ax)
Visualizations.efield_2d(sim2d, graph_ax=ax)
Visualizations.contour_2d(sim2d, graph_ax=ax)
plt.show()

# %% [markdown]
# ### Open Cylinder

# %%
sim = libem.EMSimulationSpace3D(space_size=(2, 2, 2), top_left=(-1, -1, -1), scale=25)   
cyl1_mask = EMObjectMasks.open_cylinder_in_plane(sim, (0.25, 0, 0), 0.5, 0.05, 0.5, 0, -1)
sim.compute(make_enforcer(
    enf(EMObjects.arbitrary_mask, cyl1_mask, 1)
))
print("Done.")
# Out:
# Done.

# %%
Visualizations.colormesh_3d(sim, size=(8, 8), resolution=1, color_norm=1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=0, location=0)
Visualizations.colormesh_2d(sim2d, graph_ax=ax)
Visualizations.efield_2d(sim2d, graph_ax=ax)
Visualizations.contour_2d(sim2d, graph_ax=ax)
plt.show()
