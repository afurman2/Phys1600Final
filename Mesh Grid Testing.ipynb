# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import libem
import numpy as np
from libvis import Visualizations
import matplotlib.pyplot as plt

from components import *

# %%
def generate_space(V_out=1, V_in=-1, grate_sp=0.2, th=0.05, scale=20):
    sim = libem.EMSimulationSpace3D(space_size=(4, 2, 2), top_left=(-2, -1, -1), scale=scale)
    sim.compute(make_enforcer(
        enf(EMObjects.planar_mesh_3d, (0.5, -0.8, -0.8), 0, (0.1, 1.6, 1.6), (grate_sp, grate_sp), th, V_out),
        enf(EMObjects.planar_mesh_3d, (0, -0.8, -0.8), 0, (0.1, 1.6, 1.6), (grate_sp, grate_sp), th, V_in),
        enf(EMObjects.planar_mesh_3d, (-0.5, -0.8, -0.8), 0, (0.1, 1.6, 1.6), (grate_sp, grate_sp), th, V_out),
    ))
    sim.get_efield()
    return sim

# %%
OUTER_V = 0
INNER_V = -1
sim = generate_space(OUTER_V, INNER_V, 0.2, 0.02, 50)
#sim.save("grid_sim_ON")
#sim = libem.EMSimulationSpace.load("grid_sim_ON.npy")

# %%
time_ranges = []
trajectories = []
blocked = []

end_time = 7
n_particles = 10

y_radius = 0.01
z_radius = 0.01
xv_bias = -0.3
xv_radius = 0.01
yv_radius = 0.03
zv_radius = 0.03

boundary = -0.5

print("Simulating particles:")
for i in range(n_particles):
    print("\r", i+1, end="")
    
    x = 1.8
    y = max(-y_radius, min(y_radius, np.random.normal(scale=y_radius)))
    z = max(-z_radius, min(z_radius, np.random.normal(scale=z_radius)))
    xv = max(xv_bias-xv_radius, min(xv_bias+xv_radius, np.random.normal(loc=xv_bias, scale=xv_radius)))
    yv = max(-yv_radius, min(yv_radius, np.random.normal(scale=yv_radius)))
    zv = max(-zv_radius, min(zv_radius, np.random.normal(scale=zv_radius)))
    
    p = libem.ChargedParticle3D(sim, 0.1, -1, (x, y, z), (xv, yv, zv), bounce=0.5)
    p.compute_motion((0, end_time))
    
    time_ranges.append(p.time)
    trajectories.append(p.position)
    blocked.append(p.position[0,-1] > boundary)
    
print("\rDone.")

print(len([b for b in blocked if not b]), "were not blocked.")
# Out:
# Simulating particles:
#  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-72098b2a0d56> in <module>
#      27
#      28     p = libem.ChargedParticle3D(sim, 0.1, -1, (x, y, z), (xv, yv, zv), bounce=0.5)
# ---> 29     p.compute_motion((0, end_time))
#      30
#      31     time_ranges.append(p.time)
#
# ~\Google Drive (adam_furman@brown.edu)\PHYS 1600\Phys1600Final\Phys1600Final\libem.py in compute_motion(self, t_span)
#     326         while total_time < t_span[1]:
#     327             try:
# --> 328                 p_res = ChargedParticle.compute_motion(self, (total_time, t_span[1]))
#     329                 time_partial.append(p_res.t)
#     330                 position_partial.append(np.array([p_res.y[0], p_res.y[1], p_res.y[2]]))
#
# ~\Google Drive (adam_furman@brown.edu)\PHYS 1600\Phys1600Final\Phys1600Final\libem.py in compute_motion(self, t_span, stop_cond)
#     289             stop_cond = ChargedParticle.make_terminating_function(stop_cond)
#     290         stop_events = ([term_event] if not self.bounce is None else []) + ([stop_cond] if not stop_cond is None else [])
# --> 291         return solve_ivp(self.eom, t_span,
#     292                          y0=np.ravel([self.initial_location, self.initial_velocity]),
#     293                          method="DOP853", max_step=(1.0 / self.sim.scale),
#
# ~\AppData\Roaming\Python\Python38\site-packages\scipy\integrate\_ivp\ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     574     status = None
#     575     while status is None:
# --> 576         message = solver.step()
#     577
#     578         if solver.status == 'finished':
#
# ~\AppData\Roaming\Python\Python38\site-packages\scipy\integrate\_ivp\base.py in step(self)
#     179         else:
#     180             t = self.t
# --> 181             success, message = self._step_impl()
#     182
#     183             if not success:
#
# ~\AppData\Roaming\Python\Python38\site-packages\scipy\integrate\_ivp\rk.py in _step_impl(self)
#     142             h_abs = np.abs(h)
#     143
# --> 144             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                                    self.B, self.C, self.K)
#     146             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#
# ~\AppData\Roaming\Python\Python38\site-packages\scipy\integrate\_ivp\rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      62     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63         dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64         K[s] = fun(t + c * h, y + dy)
#      65
#      66     y_new = y + h * np.dot(K[:-1].T, B)
#
# ~\AppData\Roaming\Python\Python38\site-packages\scipy\integrate\_ivp\base.py in fun(t, y)
#     136         def fun(t, y):
#     137             self.nfev += 1
# --> 138             return self.fun_single(t, y)
#     139
#     140         self.fun = fun
#
# ~\AppData\Roaming\Python\Python38\site-packages\scipy\integrate\_ivp\base.py in fun_wrapped(t, y)
#      18
#      19     def fun_wrapped(t, y):
# ---> 20         return np.asarray(fun(t, y), dtype=dtype)
#      21
#      22     return fun_wrapped, y0
#
# ~\Google Drive (adam_furman@brown.edu)\PHYS 1600\Phys1600Final\Phys1600Final\libem.py in eom(self, t, y)
#     313         x = np.array([y[0], y[1], y[2]])
#     314         v = np.array([y[3], y[4], y[5]])
# --> 315         return np.ravel([v, ((self.charge / self.mass) * self.sim.E_at(x)) - self.gravity])
#     316
#     317     def compute_motion(self, t_span):
#
# ~\Google Drive (adam_furman@brown.edu)\PHYS 1600\Phys1600Final\Phys1600Final\libem.py in E_at(self, location)
#     169
#     170         values = np.copy(self.E[:,i-1:i+2,j-1:j+2,k-1:k+2])
# --> 171         close_points = np.indices(values.shape[1:])
#     172         close_points[:,:,:] += np.array([i-1, j-1, k-1])
#     173         close_locations = (close_points / self.scale) + self.top_left
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\core\numeric.py in indices(dimensions, dtype, sparse)
#    1744         res = empty((N,)+dimensions, dtype=dtype)
#    1745     for i, dim in enumerate(dimensions):
# -> 1746         idx = arange(dim, dtype=dtype).reshape(
#    1747             shape[:i] + (dim,) + shape[i+1:]
#    1748         )
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(1, 3, figsize=(30, 10))
for i, ax in enumerate(axes):
    sim2d = libem.EMSimulationSpace2D.from_3d(sim, axis=i)
    Visualizations.colormesh_2d(sim2d, color_norm=max(abs(OUTER_V), abs(INNER_V), 1), graph_ax=ax)
    for p in range(len(trajectories)):
        Visualizations.trajectory_2d(time_ranges[p], trajectories[p], axis=i, graph_ax=ax)

# %%
plt.figure(figsize=(15, 15))
ax = plt.axes(projection='3d')

Visualizations.colormesh_3d(sim, resolution=1, color_norm=max(abs(OUTER_V), abs(INNER_V), 1), graph_ax=ax)
for p in range(len(trajectories)):
    Visualizations.trajectory_3d(time_ranges[p], trajectories[p], graph_ax=ax)
plt.show()
